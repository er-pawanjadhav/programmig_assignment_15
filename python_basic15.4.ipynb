# %%
a = input("enter email id : ")
e = ''
l = []
for i in a:
    if i =='@':
        l.append(e)
        break
    else:
        e =e+i
print("username is : ",l[0])
# Out:
# enter email id :  john@google.com
# username is :  john
