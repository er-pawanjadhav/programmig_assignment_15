# %%
# question 2
def even_gen(n,a):
    for j in range(0, n+1):
        if j % 2 == 0:
            yield j
            if j ==l[a]:
                yield ''
            else:
                yield ','

                  
n = int(input())
l = []
for i in range(n+1):
    if i%2==0:
        l.append(i)
a =len(l)-1
    
for j in even_gen(n,a):
    print(j,end='')
